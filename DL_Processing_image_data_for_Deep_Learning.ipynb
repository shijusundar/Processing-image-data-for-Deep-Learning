# %% [markdown]
# ***Processing image data for Deep Learning***

# %%
# getting an image using web get
# !wget 'https://i.pinimg.com/564x/36/b4/ef/36b4ef433ac9c2cf9d34e54aa3a38340.jpg'
# Out:
# --2023-10-25 16:55:54--  https://i.pinimg.com/564x/36/b4/ef/36b4ef433ac9c2cf9d34e54aa3a38340.jpg
# Resolving i.pinimg.com (i.pinimg.com)... 104.96.163.196, 104.96.163.213, 2a04:4e42:5::84
# Connecting to i.pinimg.com (i.pinimg.com)|104.96.163.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49435 (48K) [image/jpeg]
# Saving to: ‘36b4ef433ac9c2cf9d34e54aa3a38340.jpg’
#
# 36b4ef433ac9c2cf9d3 100%[===================>]  48.28K  --.-KB/s    in 0.009s
#
# 2023-10-25 16:55:54 (4.96 MB/s) - ‘36b4ef433ac9c2cf9d34e54aa3a38340.jpg’ saved [49435/49435]

# %% [markdown]
# **Libraries that can be used for image processing:**
#
# 1. matplotlib.image
#
# 2. Pillow
#
# 3. OpenCV (cv2)

# %%
#importing image module from matplotlib library

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
# loading an image through matplotlib.image module

img = mpimg.imread('/content/puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (500, 500, 3)

# %%
print(img)

# %%
# displaying the image from numpy array

img_plot = plt.imshow(img)
plt.show()

# %% [markdown]
# Resizing the image using Pillow library

# %%
from PIL import Image

# %%
img = Image.open('/content/puppy.jpg')
img_resized = img.resize((200,200))

# %%
img_resized.save('puppy_resized.jpg')

# %%
# displaying the image from numpy array

img_re = mpimg.imread('/content/puppy_resized.jpg')
img_re_plot = plt.imshow(img_re)
plt.show()

# %%
img_re.shape
# Out:
# (200, 200, 3)

# %% [markdown]
# **Converting RGB images to Grayscale image using OpenCV**

# %%
# importing OpenCV library
import cv2

# %%
img = cv2.imread('/content/puppy.jpg')

# %%
img.shape
# Out:
# (500, 500, 3)

# %%
grayscale_image = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (500, 500)

# %% [markdown]
# cv2.imshow() will display the image. But this will not be allowed in Google Colab.
#
# **from google.colab.patches import cv2_imshow**

# %%
from google.colab.patches import cv2_imshow

# %%
# displaying the image
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=500x500>

# %%
#saving the grayscale image
cv2.imwrite('puppy_grayscale.jpg',grayscale_image)
# Out:
# True
